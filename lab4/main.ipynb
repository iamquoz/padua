# %%
import pandas as pd

df = pd.read_csv('metro.tsv', sep='\t')

df.head()
# Out:
#               Название    Широта   Долгота
# 0             Аэропорт  55.79981  37.53412
# 1        Академическая  55.68808  37.57501
# 2         Алексеевская  55.80737  37.63844
# 3  Александровский сад  55.75219  37.60836
# 4            Алтуфьево  55.89504  37.58605

# %%
def get_icons_per_district():
	icon_format = "https://domokucha.info/img/V_{0}_of_Moscow_coa.png"

	import requests
	from bs4 import BeautifulSoup
	url = 'https://domokucha.info/moscow_metro_district.html'

	response = requests.get(url)
	soup = BeautifulSoup(response.content, 'html.parser')

	for row in soup.select_one('.wrapper .container').select_one('section').select('.features-item'):
		district_name = next(row.select_one('.features-title').children, None)
		icon_url = icon_format.format(row.select_one('.features-icon')['class'][1].removeprefix('features-icon-V'))
		
		yield district_name.__str__().strip(), icon_url

# %%
def find_district_from_geojson(geojson, lat, lng): 
	import json
	from shapely.geometry import shape, Point

	with open(geojson) as f:
		data = json.load(f)

	point = Point(lng, lat)

	for feature in data['features']:
		polygon = shape(feature['geometry'])
		if polygon.contains(point):
			return feature['properties']['NAME']

	return None

# %%
dict_icons = dict(get_icons_per_district())
df['district'] = df.apply(lambda row: find_district_from_geojson('ao.geojson', row['Широта'], row['Долгота']), axis=1)
df['icon'] = df['district'].map(dict_icons)

# %%
dict_icons
# Out:
# {'Восточный': 'https://domokucha.info/img/V_VAO_district_of_Moscow_coa.png',
#  'Западный': 'https://domokucha.info/img/V_ZAO_district_of_Moscow_coa.png',
#  'Северный': 'https://domokucha.info/img/V_SAO_district_of_Moscow_coa.png',
#  'Северо-Западный': 'https://domokucha.info/img/V_SZAO_district_of_Moscow_coa.png',
#  'Северо-Восточный': 'https://domokucha.info/img/V_SVAO_district_of_Moscow_coa.png',
#  'Центральный': 'https://domokucha.info/img/V_CAO_district_of_Moscow_coa.png',
#  'Юго-Восточный': 'https://domokucha.info/img/V_UVAO_district_of_Moscow_coa.png',
#  'Юго-Западный': 'https://domokucha.info/img/V_UZAO_district_of_Moscow_coa.png',
#  'Южный': 'https://domokucha.info/img/V_UAO_district_of_Moscow_coa.png',
#  'Зеленоградский': 'https://domokucha.info/img/V_Zelenograd_district_of_Moscow_coa.png',
#  'Новомосковский': 'https://domokucha.info/img/V_new-moscow_district_of_Moscow_coa.png',
#  'Троицкий': 'https://domokucha.info/img/V_troicky_district_of_Moscow_coa.png'}

# %%
df
# Out:
#                 Название     Широта    Долгота          district  \
# 0               Аэропорт  55.799810  37.534120          Северный
# 1          Академическая  55.688080  37.575010      Юго-Западный
# 2           Алексеевская  55.807370  37.638440  Северо-Восточный
# 3    Александровский сад  55.752190  37.608360       Центральный
# 4              Алтуфьево  55.895040  37.586050  Северо-Восточный
# ..                   ...        ...        ...               ...
# 160       Воробьёвы горы  55.710454  37.558601       Центральный
# 161               Выхино  55.715000  37.818020     Юго-Восточный
# 162              Ясенево  55.605350  37.534940      Юго-Западный
# 163         Юго-западная  55.664640  37.484210          Западный
# 164                Южная  55.621220  37.607520             Южный
#
#                                                   icon
# 0    https://domokucha.info/img/V_SAO_district_of_M...
# 1    https://domokucha.info/img/V_UZAO_district_of_...
# 2    https://domokucha.info/img/V_SVAO_district_of_...
# 3    https://domokucha.info/img/V_CAO_district_of_M...
# 4    https://domokucha.info/img/V_SVAO_district_of_...
# ..                                                 ...
# 160  https://domokucha.info/img/V_CAO_district_of_M...
# 161  https://domokucha.info/img/V_UVAO_district_of_...
# 162  https://domokucha.info/img/V_UZAO_district_of_...
# 163  https://domokucha.info/img/V_ZAO_district_of_M...
# 164  https://domokucha.info/img/V_UAO_district_of_M...
#
# [165 rows x 5 columns]

# %%
import folium

m = folium.Map(location=[df['Широта'].mean(), df['Долгота'].mean()], zoom_start=10)


for idx, row in df.iterrows():
	folium.Marker(
		icon=folium.CustomIcon(
			icon_image=row['icon'],
			 icon_size=(45, 45),
		),
		location=[row['Широта'], row['Долгота']],
		popup='<b>Станция: {}</b><br>Район: {}<br> {};{}'.format(row['Название'], row['district'], row['Широта'], row['Долгота']),
	).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8490e7e7bbbb7468f56c1012a52567e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8490e7e7bbbb7468f56c1012a52567e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8490e7e7bbbb7468f56c1012a52567e = L.map(
#                 &quot;map_b8490e7e7bbbb7468f56c1012a52567e&quot;,
#                 {
#                     center: [55.742647739393945, 37.61498712121213],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b7577a9f01aa8647890c9369bdd73d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4b7577a9f01aa8647890c9369bdd73d8.addTo(map_b8490e7e7bbbb7468f56c1012a52567e);
#
#
#             var marker_388bab23f51c89c3e8fb46c9267dfb2d = L.marker(
#                 [55.79981, 37.53412],
#                 {}
#             ).addTo(map_b8490e7e7bbbb7468f56c1012a52567e);
#
#
#         var custom_icon_73ec5b612df86e08c0022610bd730b51 = L.icon({&quot;iconSize&quot;: [45, 45], &quot;iconUrl&quot;: &quot;https://domokucha.info/img/V_SAO_district_of_Moscow_coa.png&quot;});
#         marker_388bab23f51c89c3e8fb46c9267dfb2d.setIcon(custom_icon_73ec5b612df86e08c0022610bd730b51);
#
#
#         var popup_c38b47f6b79f64c7f816eb02780fbb8c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d2fb6576e6baea16804e87e4d39b74a9 = $(`&lt;div id=&quot;html_d2fb6576e6baea16804e87e4d39b74a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Станция: Аэропорт&lt;/b&gt;&lt;br&gt;Район: Северный&lt;br&gt; 55.79981;37.53412&lt;/div&gt;`)[0];
#                 popup_c38b47f6b79f64c7f816eb02780fbb8c.setContent(html_d2fb6576e6baea16804e87e4d39b74a9);
#
#
#
#         marker_388bab23f51c89c3e8fb46c9267dfb2d.bindPopup(popup_c38b47f6b79f64c7f816eb02780fbb8c)
#         ;
#
#
#
#
#             var marker_39c8d932c80886ac51faf7d4a4edb9b1 = L.marker(
#                 [55.68808, 37.57501],
#                 {}
#             ).addTo(map_b8490e7e7bbbb7468f56c1012a52567e);
#
#
#         var custom_icon_eefc34ee65df2191b5caf890e567d613 = L.icon({&quot;iconSize&quot;: [45, 45], &quot;iconUrl&quot;: &quot;https://domokucha.info/img/V_UZAO_district_of_Moscow_coa.png&quot;});
#         marker_39c8d932c80886ac51faf7d4a4edb9b1.setIcon(custom_icon_eefc34ee65df2191b5caf890e567d613);
#
#
#         var popup_d7f120a6a176aef7f6373d3592ea7e4e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5849900a6e3c8ccd3b6576061797f258 = $(`&lt;div id=&quot;html_5849900a6e3c8ccd3b6576061797f258&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Станция: Академическая&lt;/b&gt;&lt;br&gt;Район: Юго-Западный&lt;br&gt; 55.68808;37.57501&lt;/div&gt;`)[0];
#                 popup_d7f120a6a176aef7f6373d3592ea7e4e.setContent(html_5849900a6e3c8ccd3b6576061797f258);
#
#
#
#         marker_39c8d932c80886ac51faf7d4a4edb9b1.bindPopup(popup_d7f120a6a176aef7f6373d3592ea7e4e)
#         ;
#
#
#
#
#             var marker_c7dfb4553791a937892070aba91874c6 = L.marker(
#                 [55.80737, 37.63844],
#                 {}
#             ).addTo(map_b8490e7e7bbbb7468f56c1012a52567e);
#
#
#         var custom_icon_9209547dcc7272ddb20ed00e0f53dc1c = L.icon({&quot;iconSize&quot;: [45, 45], &quot;iconUrl&quot;: &quot;https://domokucha.info/img/V_SVAO_district_of_Moscow_coa.png&quot;});
#         marker_c7dfb4553791a937892070aba91874c6.setIcon(custom_icon_9209547dcc7272ddb20ed00e0f53dc1c);
#
#
#         var popup_3b8ff8640e33f46aacbf032165eb3df3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea26dd45ae81b5dbefe7ea73a832374e = $(`&lt;div id=&quot;html_ea26dd45ae81b5dbefe7ea73a832374e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Станция: Алексеевская&lt;/b&gt;&lt;br&gt;Район: Северо-Восточный&lt;br&gt; 55.80737;37.63844&lt;/div&gt;`)[0];
#                 popup_3b8ff8640e33f46aacbf032165eb3df3.setContent(html_ea26dd45ae81b5dbefe7ea73a832374e);
#
#
#
#         marker_c7dfb4553791a937892070aba91874c6.bindPopup(popup_3b8ff8640e33f46aacbf032165eb3df3)
#         ;
#
#
#
#
#             var marker_942bc5e5d67077a5746e15ff64896120 = L.marker(
#                 [55.75219, 37.60836],
#                 {}
#             ).addTo(map_b8490e7e7bbbb7468f56c1012a52567e);
#
#
#         var custom_icon_51e387e4e96f018a51c06249f05ac787 = L.icon({&quot;iconSize&quot;: [45, 45], &quot;iconUrl&quot;: &quot;https://domokucha.info/img/V_CAO_district_of_Moscow_coa.png&quot;});
#         marker_942bc5e5d67077a5746e15ff64896120.setIcon(custom_icon_51e387e4e96f018a51c06249f05ac787);
#
#
#         var popup_494a9ed70edec9ea4c1006541d9a1dea = L.popup(
