# %%
MIN_RESOLUTION = 400

# %%
url = input()

# %%
from urllib.parse import urljoin


def convert_image_to_jpg(src):
	import requests
	from PIL import Image
	from io import BytesIO
	response = requests.get(urljoin(url, src))
	img = Image.open(BytesIO(response.content))
	
	img = img.resize(img.size)

	if img.size[0] < MIN_RESOLUTION or img.size[1] < MIN_RESOLUTION:
		ratio = max(MIN_RESOLUTION / img.size[0], MIN_RESOLUTION / img.size[1])
		new_size = (int(img.size[0] * ratio), int(img.size[1] * ratio))
		img = img.resize(new_size, Image.ANTIALIAS)

	return img

# %%
def find_all_images(url):
	import requests
	from bs4 import BeautifulSoup
	response = requests.get(url)
	soup = BeautifulSoup(response.text, 'html.parser')
	images = soup.find_all(['img', 'picture'])

	print(response.text)

	return [convert_image_to_jpg(image['src'] or image['source']) for image in images if 'src' in image.attrs or 'source' in image.attrs]

# %%
def pack_zip_file(images):
	import os
	import zipfile
	import io
	zip_file = io.BytesIO()
	with zipfile.ZipFile(zip_file, 'w') as z:
		for i, image in enumerate(images):
			image.save(f'img{i}.jpg', 'JPEG')
			z.write(f'img{i}.jpg')
			os.remove(f'img{i}.jpg')

	zip_file.seek(0)

	with open('images.zip', 'wb') as f:
		f.write(zip_file.getvalue())

# %%
def zip_to_yolov8_directory(zip_file):
	import zipfile, io
	import os
	import glob

	from sklearn.model_selection import train_test_split
	zip_file = zipfile.ZipFile(io.BytesIO(zip_file.read()))

	os.makedirs('train', exist_ok=True)
	os.makedirs('val', exist_ok=True)

	existing_files = glob.glob('train/*.jpg') + glob.glob('val/*.jpg')
	for file in existing_files:
		os.remove(file)

	
	image_files = [f for f in zip_file.namelist() if f.endswith('.jpg')]
	train_files, val_files = train_test_split(image_files, test_size=0.2)

	for file in train_files:
		with zip_file.open(file) as source, open(os.path.join('train', file), 'wb') as target:
			target.write(source.read())

	for file in val_files:
		with zip_file.open(file) as source, open(os.path.join('val', file), 'wb') as target:
			target.write(source.read())

# %%
pack_zip_file(find_all_images(url))
# Out:
# <!DOCTYPE html>
# <html lang="en" dir="ltr">
#   <head>
#     <meta charset="utf-8">
#       <title>(e:ltr cn&gt;=452) or (e:ltc cn&gt;=411) · Scryfall Magic The Gathering Search</title>
#
# <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#
# <link rel="preconnect" href="https://cards.scryfall.io" crossorigin="true" />
# <link rel="dns-prefetch" href="https://cards.scryfall.io" />
#
# <meta name="description" content="550 Magic cards found where (the set is “ltr” and the collector number &gt;= 452) or (the set is “ltc” and the collector number &gt;= 411)" />
#
#
#
#
# <link rel="alternate" type="application/atom+xml" title="ATOM" href="https://scryfall.com/blog/feed" />
#
# <link rel="search" type="application/opensearchdescription+xml" title="Scryfall" href="https://scryfall.com/opensearch.xml" />
#
# <meta property="og:site_name" content="Scryfall Magic The Gathering Search" />
# <meta property="og:type" content="website" />
# <meta property="og:title" content="(e:ltr cn&gt;=452) or (e:ltc cn&gt;=411)" />
# <meta property="og:description" content="550 Magic cards found where (the set is “ltr” and the collector number &gt;= 452) or (the set is “ltc” and the collector number &gt;= 411)" />
# <meta property="og:url" content="https://scryfall.com/search" />
# <meta property="og:image" content="https://scryfall.com/icon.png?v=67d7e1c8f09f" />
#
# <meta name="twitter:creator" content="@scryfall" />
# <meta name="twitter:site" content="@scryfall" />
# <meta name="twitter:domain" content="https://scryfall.com/" />
# <meta name="twitter:card" content="summary" />
#
# <meta name="twitter:image" content="https://scryfall.com/apple-touch-icon.png?67d7e1c8f09f?v=67d7e1c8f09f" />
# <meta name="twitter:title" content="(e:ltr cn&gt;=452) or (e:ltc cn&gt;=411)" />
# <meta name="twitter:description" content="550 Magic cards found where (the set is “ltr” and the collector number &gt;= 452) or (the set is “ltc” and the collector number &gt;= 411)" />
#
#
#
#
#
#
#
#
#
#
# <link rel="icon" type="image/x-icon" href="https://scryfall.com/favicon.ico?v=67d7e1c8f09f" />
#
# <meta name="apple-mobile-web-app-title" content="Scryfall" />
# <link rel="manifest" href="https://scryfall.com/manifest.webmanifest?v=67d7e1c8f09f" />
# <link rel="apple-touch-icon" href="https://scryfall.com/apple-touch-icon.png?v=67d7e1c8f09f" />
# <link rel="icon" sizes="196x196" href="https://scryfall.com/icon-196.png?v=67d7e1c8f09f" />
# <link rel="icon" sizes="512x512" href="https://scryfall.com/icon-512.png?v=67d7e1c8f09f" />
#
# <meta name="impact-site-verification" value="281e0b67-6b5a-4f31-b430-c7c0cc421775" />
#
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"Organization","url":"https://scryfall.com","logo":"https://scryfall.com/icon.png?v=67d7e1c8f09f"}</script>
#
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"WebSite","url":"https://scryfall.com","potentialAction":{"@type":"SearchAction","target":"https://scryfall.com/search?q={terms}&utm_source=google","query-input":"required name=terms"}}</script>
#
#
#
#     <link rel="stylesheet" href="https://scryfall.com/assets/scryfall-bc8ba003a9b645c0d63542823d62ebbf0cf044bd0c5c2dc416d3dab3a426199f.css" media="all" />
#   </head>
#   <body>
#     <div class="skip-links">
#   <ul>
#     <li><a href="#main">Skip to main content</a></li>
#     <li><a href="#footer">Skip to footer</a></li>
#   </ul>
# </div>
#
#
#     <div id="header" class="header" data-component="header" role="nav">
#
#   <div class="header-control-row">
#
#     <a class="header-logo" title="Back to homepage" href="/">
#       <span class="vh">Scryfall</span>
#       <svg focusable="false"  aria-hidden="true"  width="460" height="460" viewBox="0 0 460 460" xmlns="http://www.w3.org/2000/svg"><g transform="translate(-60 -58)" fill="none" fill-rule="evenodd"><circle fill="#000" opacity=".09" cx="290" cy="288" r="230"/><path fill="#BC979D" d="M279.508 112.547l-.028 361.84 43.137 6.808 56.715-13.23 28.54-72.547-28.044-178.926-31.887-113.004"/><path fill="#AE7F9C" d="M281.57 100.633l-2.457 383.13-67.972-21.888 13.9-355.852"/><path d="M207.05 113.316v344.032S87.364 394.5 93.388 283.043C99.41 171.586 207.05 113.316 207.05 113.316z" fill="#786076"/><path d="M237.375 107.21l-30.603 4.35s-20.682 10.42-37.922 25.5c-75.19 167.948 108.332 115.1-12.725 286.69 50.647 47.86 72.293 41.137 72.293 41.137l8.957-357.676z" fill="#947A92"/><path d="M343.058 89.985c-109.36-29.303-221.77 35.597-251.073 144.957-29.303 109.36 35.597 221.77 144.957 251.073 109.36 29.303 221.77-35.597 251.073-144.957 29.303-109.36-35.597-221.77-144.957-251.073zM256.342 451.95l.276.71c1.172 3.187 3.562 5.776 6.644 7.2 3.082 1.422 6.603 1.562 9.788.387l48.355-17.774c3.184-1.175 6.
#
#         <input type="hidden" name="unique" id="unique" value="prints" autocomplete="off" />
#
#         <input type="hidden" name="as" id="as" value="grid" autocomplete="off" />
#
#         <input type="hidden" name="order" id="order" value="set" autocomplete="off" />
#
#
#       <button type="submit" class="vh">
#         Find Cards
# </button>
# </form>
#     <div class="header-links">
#
#       <div class="header-link-divider"></div>
#
#       <a class="header-link double-pad-left" href="/advanced">
#         <svg width="30" height="30" viewBox="0 0 30 30" aria-hidden="true" focusable="false" xmlns="http://www.w3.org/2000/svg"><path d="M10 6h-4v2h4v-2zm14 0h-12v2h12v-2zm-22-4v26h26v-26h-26zm24 24h-22v-14h22v14zm0-16h-22v-6h22v6z"/></svg>
#
#         <span>Advanced</span>
# </a>
#       <a class="header-link" href="/docs/syntax">
#         <svg width="30" height="30" viewBox="0 0 30 30" aria-hidden="true" focusable="false" xmlns="http://www.w3.org/2000/svg"><path d="M15 0c-8.284 0-15 6.716-15 15s6.716 15 15 15 15-6.716 15-15-6.716-15-15-15zm0 28c-7.18 0-13-5.82-13-13s5.82-13 13-13 13 5.82 13 13-5.82 13-13 13zm-1-4h2v-4h-2v4zm1-18c-2.958 0-5.2 1.834-5.2 5h2c0-2.041 1.389-3 3.2-3 1.598 0 3 .935 3 2 0 3.281-4 2.656-4 8h2c-.146-4.063 4-3.646 4-8 0-2.209-2.238-4-5-4z"/></svg>
#
#         <span>Syntax</span>
# </a>
#       <a class="header-link" href="/sets">
#         <svg width="30" height="30" viewBox="0 0 30 30" aria-hidden="true" focusable="false" xmlns="http://www.w3.org/2000/svg"><path d="M15 2c-3.296 5.789-5.713 13.983-15 6l4 12v8h22v-8l4-12c-9.287 7.983-11.704-.211-15-6zm-9 24v-4h18v4h-18zm18-6.324v.324h-18v-.324l-2.32-6.962c5.055 1.849 8.383-.683 11.32-6.475 2.938 5.792 6.266 8.323 11.32 6.475l-2.32 6.962z"/></svg>
#
#         <span>Sets</span>
# </a>
#       <a class="header-link double-pad-right" href="/random">
#         <svg width="30" height="30" viewBox="0 0 30 30" aria-hidden="true" focusable="false" xmlns="http://www.w3.org/2000/svg"><path d="M20.594 18.406l3.594 3.594h-6.188l-.341-.034c-.229.655-.569 1.256-.997 1.786.421.151.867.248 1.338.248h6.188l-3.594 3.594 1.406 1.406 6-6-6-6-1.406 1.406zm3.594-10.406l-3.594 3.594 1.406 1.406 6-6-6-6-1.406 1.406 3.594 3.594h-6.188c-2.2 0-4 1.8-4 4v10c0 1.103-.897 2-2 2h-10v2h10c2.2 0 4-1.8 4-4v-10c0-1.103.896-2 2-2h6.188zm-11.848.034c.229-.654.565-1.258.993-1.787-.419-.15-.864-.247-1.333-.247h-10v2h10l.34.034z"/></svg>
#
#         <span>Random</span>
# </a>
#       <div class="header-link-divider"></div>
#
#       <a title="Your decks" class="header-link icon-only" href="/account/decks">
#         <svg focusable="false"  aria-hidden="true"  xmlns="http://www.w3.org/2000/svg" viewBox="0 0 448 512"><path d="M320 64h-16V48c0-26.47-21.53-48-48-48h-64c-26.47 0-48 21.53-48 48v16h-16C57.31 64 0 121.31 0 192v256c0 35.35 28.65 64 64 64h320c35.35 0 64-28.65 64-64V192c0-70.69-57.31-128-128-128zM176 48c0-8.83 7.19-16 16-16h64c8.81 0 16 7.17 16 16v16h-96V48zm160 432H112v-96h224v96zm0-128H112v-32c0-17.67 14.33-32 32-32h160c17.67 0 32 14.33 32 32v32zm80 96c0 17.64-14.36 32-32 32h-16V320c0-35.29-28.71-64-64-64H144c-35.29 0-64 28.71-64 64v160H64c-17.64 0-32-14.36-32-32V192c0-52.94 43.06-96 96-96h192c52.94 0 96 43.06 96 96v256zM312 160H136c-4.42 0-8 3.58-8 8v16c0 4.42 3.58 8 8 8h176c4.42 0 8-3.58 8-8v-16c0-4.42-3.58-8-8-8z"/></svg>
#
#         <span class="vh">Your decks</span>
# </a>
#       <a title="Your account" class="header-link icon-only" href="/settings">
#         <svg focusable="false"  aria-hidden="true"  xmlns="http://www.w3.org/2000/svg" viewBox="0 0 512 512"><path d="M256 8C119.033 8 8 119.033 8 256s111.033 248 248 248 248-111.033 248-248S392.967 8 256 8zm0 32c118.663 0 216 96.055 216 216 0 45.887-14.373 88.578-38.928 123.692-11.413-36.912-44.537-64.38-84.385-67.413C371.483 288.374 384 257.149 384 224c0-70.741-57.249-128-128-128-70.74 0-128 57.249-128 128 0 33.149 12.517 64.374 35.313 88.279-39.861 3.033-72.994 30.519-84.396 67.45C54.424 344.761 40 302.154 40 256c0-118.663 96.055-216 216-216zm-96 184c0-53.019 42.981-96 96-96s96 42.981 96 96-42.981 96-96 96-96-42.981-96-96zm-53.333 188.058c0-43.808 31.782-68.058 64-68.058h40.622c28.662 10.663 60.712 10.68 89.422 0h40.622c32.717 0 64 24.665 64 68.073-83.416 79.913-215.066 79.926-298.666-.015z"/></svg>
#
#         <span class="vh">Sign In</span>
# </a>
#     </div>
#
#     <button type="button" class="header-menu-button-container" v-on:click="toggleMobileNav()">
#       <span class="button-n inverted header-menu-button">
#         <svg width="30" height="30" viewBox="0 0 30 30" aria-hidden="true" focusable="false" xmlns="http://www.w3.org/2000/svg"><path d="M2 4v2h26v-2h-26zm0 12h26v-2h-26v2zm0 10h26v-2h-26v2z"/></svg>
#
#         <b class="header-menu-button-label">Menu</b>
#       </span>
#     </button>
#
#   </div>
#
#   <div class="mobile-nav" v-cloak v-if="mobileNavOpen">
#
#     <a class="button-n inverted align-left" href="/advanced">
#       <svg width="30" height="30" viewBox="0 0 30 30" aria-hidden="true" focusable="false" xmlns="http://www.w3.org/2000/svg"><path d="M10 6h-4v2h4v-2zm14 0h-12v2h12v-2zm-22-4v26h26v-26h-26zm24 24h-22v-14h22v14zm0-16h-22v-6h22v6z"/></svg>
#
#       <b>Advanced Search</b>
# </a>
#     <a class="button-n inverted align-left" href="/docs/syntax">
#       <svg width="30" height="30" viewBox="0 0 30 30" aria-hidden="true" focusable="false" xmlns="http://www.w3.org/2000/svg"><path d="M15 0c-8.284 0-15 6.716-15 15s6.716 15 15 15 15-6.716 15-15-6.716-15-15-15zm0 28c-7.18 0-13-5.82-13-13s5.82-13 13-13 13 5.82 13 13-5.82 13-13 13zm-1-4h2v-4h-2v4zm1-18c-2.958 0-5.2 1.834-5.2 5h2c0-2.041 1.389-3 3.2-3 1.598 0 3 .935 3 2 0 3.281-4 2.656-4 8h2c-.146-4.063 4-3.646 4-8 0-2.209-2.238-4-5-4z"/></svg>
#
#       <b>Syntax Guide</b>
# </a>
#     <a class="button-n inverted align-left" href="/sets">
#       <svg width="30" height="30" viewBox="0 0 30 30" aria-hidden="true" focusable="false" xmlns="http://www.w3.org/2000/svg"><path d="M15 2c-3.296 5.789-5.713 13.983-15 6l4 12v8h22v-8l4-12c-9.287 7.983-11.704-.211-15-6zm-9 24v-4h18v4h-18zm18-6.324v.324h-18v-.324l-2.32-6.962c5.055 1.849 8.383-.683 11.32-6.475 2.938 5.792 6.266 8.323 11.32 6.475l-2.32 6.962z"/></svg>
#
#       <b>All Sets</b>
# </a>
#     <a class="button-n inverted align-left" href="/random">
#       <svg width="30" height="30" viewBox="0 0 30 30" aria-hidden="true" focusable="false" xmlns="http://www.w3.org/2000/svg"><path d="M20.594 18.406l3.594 3.594h-6.188l-.341-.034c-.229.655-.569 1.256-.997 1.786.421.151.867.248 1.338.248h6.188l-3.594 3.594 1.406 1.406 6-6-6-6-1.406 1.406zm3.594-10.406l-3.594 3.594 1.406 1.406 6-6-6-6-1.406 1.406 3.594 3.594h-6.188c-2.2 0-4 1.8-4 4v10c0 1.103-.897 2-2 2h-10v2h10c2.2 0 4-1.8 4-4v-10c0-1.103.896-2 2-2h6.188zm-11.848.034c.229-.654.565-1.258.993-1.787-.419-.15-.864-.247-1.333-.247h-10v2h10l.34.034z"/></svg>
#
#       <b>Random Card</b>
# </a>
#     <a class="button-n inverted align-left" v-if="Scryfall.accountIsNotSignedIn()" href="/account/decks">
#       <svg focusable="false"  aria-hidden="true"  xmlns="http://www.w3.org/2000/svg" viewBox="0 0 512 512"><path d="M256 8C119.033 8 8 119.033 8 256s111.033 248 248 248 248-111.033 248-248S392.967 8 256 8zm0 32c118.663 0 216 96.055 216 216 0 45.887-14.373 88.578-38.928 123.692-11.413-36.912-44.537-64.38-84.385-67.413C371.483 288.374 384 257.149 384 224c0-70.741-57.249-128-128-128-70.74 0-128 57.249-128 128 0 33.149 12.517 64.374 35.313 88.279-39.861 3.033-72.994 30.519-84.396 67.45C54.424 344.761 40 302.154 40 256c0-118.663 96.055-216 216-216zm-96 184c0-53.019 42.981-96 96-96s96 42.981 96 96-42.981 96-96 96-96-42.981-96-96zm-53.333 188.058c0-43.808 31.782-68.058 64-68.058h40.622c28.662 10.663 60.712 10.68 89.422 0h40.622c32.717 0 64 24.665 64 68.073-83.416 79.913-215.066 79.926-298.666-.015z"/></svg>
#
#       <b>Your Account</b>
# </a>
#     <a class="button-n inverted align-left" v-if="Scryfall.accountIsSignedIn()" href="/account/decks">
#       <svg focusable="false"  aria-hidden="true"  xmlns="http://www.w3.org/2000/svg" viewBox="0 0 448 512"><path d="M320 64h-16V48c0-26.47-21.53-48-48-48h-64c-26.47 0-48 21.53-48 48v16h-16C57.31 64 0 121.31 0 192v256c0 35.35 28.65 64 64 64h320c35.35 0 64-28.65 64-64V192c0-70.69-57.31-128-128-128zM176 48c0-8.83 7.19-16 16-16h64c8.81 0 16 7.17 16 16v16h-96V48zm160 432H112v-96h224v96zm0-128H112v-32c0-17.67 14.33-32 32-32h160c17.67 0 32 14.33 32 32v32zm80 96c0 17.64-14.36 32-32 32h-16V320c0-35.29-28.71-64-64-64H144c-35.29 0-64 28.71-64 64v160H64c-17.64 0-32-14.36-32-32V192c0-52.94 43.06-96 96-96h192c52.94 0 96 43.06 96 96v256zM312 160H136c-4.42 0-8 3.58-8 8v16c0 4.42 3.58 8 8 8h176c4.42 0 8-3.58 8-8v-16c0-4.42-3.58-8-8-8z"/></svg>
#
#       <b>Your Decks</b>
# </a>
#     <a class="button-n inverted align-left" v-if="Scryfall.accountIsSignedIn()" href="/account/decks/new">
#       <svg focusable="false"  aria-hidden="true"  xmlns="http://www.w3.org/2000/svg" width="30" height="30" viewBox="0 0 30 30"><path fill="#5822AC" d="M15 0c-8.284 0-15 6.716-15 15s6.716 15 15 15 15-6.716 15-15-6.716-15-15-15zm0 28c-7.18 0-13-5.82-13-13s5.82-13 13-13 13 5.82 13 13-5.82 13-13 13zm1-22h-2v8h-8v2h8v8h2v-8h8v-2h-8v-8z"/></svg>
#
#       <b>New Deck</b>
# </a>
#     <button type="button" class="button-n align-left" v-bind:class="{&#39;inverted&#39;:!accountSectionOpen, &#39;inverted-white&#39;:accountSectionOpen}" v-if="Scryfall.accountIsSignedIn()" v-on:click="toggleAccountSection()">
#       <svg focusable="false"  aria-hidden="true"  xmlns="http://www.w3.org/2000/svg" viewBox="0 0 512 512"><path d="
-2 2-2zm10.949 1h-7.091c-.446-1.723-1.997-3-3.858-3-.37 0-.722.066-1.063.16l-3.544-6.139c1.403-.649 2.96-1.021 4.607-1.021 5.737 0 10.443 4.395 10.949 10zm-21.949 1c0-3.712 1.844-6.988 4.66-8.98l3.539 6.129c-.739.726-1.199 1.734-1.199 2.851s.46 2.125 1.199 2.852l-3.539 6.128c-2.816-1.992-4.66-5.268-4.66-8.98z"/></svg>
#
#       <b>Search Settings</b>
# </a>
#     <a class="button-n inverted align-left" v-if="accountSectionOpen" href="/settings/profile">
#       <svg focusable="false"  aria-hidden="true"  xmlns="http://www.w3.org/2000/svg" viewBox="0 0 512 512"><path d="M256 8C119.033 8 8 119.033 8 256s111.033 248 248 248 248-111.033 248-248S392.967 8 256 8zm0 32c118.663 0 216 96.055 216 216 0 45.887-14.373 88.578-38.928 123.692-11.413-36.912-44.537-64.38-84.385-67.413C371.483 288.374 384 257.149 384 224c0-70.741-57.249-128-128-128-70.74 0-128 57.249-128 128 0 33.149 12.517 64.374 35.313 88.279-39.861 3.033-72.994 30.519-84.396 67.45C54.424 344.761 40 302.154 40 256c0-118.663 96.055-216 216-216zm-96 184c0-53.019 42.981-96 96-96s96 42.981 96 96-42.981 96-96 96-96-42.981-96-96zm-53.333 188.058c0-43.808 31.782-68.058 64-68.058h40.622c28.662 10.663 60.712 10.68 89.422 0h40.622c32.717 0 64 24.665 64 68.073-83.416 79.913-215.066 79.926-298.666-.015z"/></svg>
#
#       <b>Your Profile</b>
# </a>
#     <a class="button-n inverted align-left" v-if="accountSectionOpen" href="/settings/security">
#       <svg focusable="false"  aria-hidden="true"  xmlns="http://www.w3.org/2000/svg" viewBox="0 0 448 512"><path d="M224 420c-11 0-20-9-20-20v-64c0-11 9-20 20-20s20 9 20 20v64c0 11-9 20-20 20zm224-148v192c0 26.5-21.5 48-48 48H48c-26.5 0-48-21.5-48-48V272c0-26.5 21.5-48 48-48h16v-64C64 71.6 136-.3 224.5 0 312.9.3 384 73.1 384 161.5V224h16c26.5 0 48 21.5 48 48zM96 224h256v-64c0-70.6-57.4-128-128-128S96 89.4 96 160v64zm320 240V272c0-8.8-7.2-16-16-16H48c-8.8 0-16 7.2-16 16v192c0 8.8 7.2 16 16 16h352c8.8 0 16-7.2 16-16z"/></svg>
#       <b>Email &amp; Security</b>
# </a>
#     <a class="button-n inverted align-left" v-if="accountSectionOpen" href="/settings/safety">
#       <svg focusable="false"  aria-hidden="true"  width="66" height="78" viewBox="0 0 66 78" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><title>Shape</title><desc>Created with Sketch.</desc><g stroke="none" stroke-width="1" fill="none" fill-rule="evenodd"><path d="M31.895,0.262 C24.27,4.9808 12.543,7.7893 3.141,4.1097 C1.9808,3.66048 0.5121,4.58626 0.4222,5.8285 C-1.6247,36.1445 4.055,52.5085 11.5472,62.1175 C19.0394,71.7269 28.2702,74.6605 31.5472,77.5355 C32.28939,78.18003 33.5238,78.14878 34.2347,77.473 C41.2816,72.6527 49.1487,68.1918 54.0467,62.149 C61.7029,52.5474 67.6517,36.157 65.5777,5.829 C65.487856,4.5868 64.0191,3.6571 62.8589,4.1102 C53.5151,7.7899 41.7569,4.99301 33.9799,0.2625 C33.21818,-0.14766 32.6166,-0.01875 31.8861,0.2625 L31.895,0.262 Z M32.9888,4.1722 C40.9224,8.6995 51.7428,11.4574 61.6798,8.6449 C63.1954,36.6139 57.629,51.2499 50.9298,59.6489 C46.0939,66.2427 38.3318,70.0239 32.8678,73.5979 C28.0709,70.0471 20.9188,67.6096 14.7118,59.6489 C8.1688,51.2583 2.8248,36.6259 4.3368,8.6449 C14.3134,11.4535 25.1688,8.715213 32.9968,4.1722 L32.9888,4.1722 Z M31.9263,12.2699 C26.9107,15.3637 19.1213,17.1879 13.0203,14.8011 C11.8445,14.32454 10.3367,15.28157 10.2703,16.5511 C8.8758,37.1331 12.7625,48.3671 17.9578,55.0161 C23.1531,61.6645 29.5948,63.7856 31.5828,65.5241 C32.32889,66.18426 33.5867,66.15691 34.3016,65.4616 C39.0985,62.2311 44.4386,59.1413 47.7706,55.0476 C53.0792,48.4109 57.1183,37.1456 55.7081,16.5516 C55.633881,15.2977 54.1612,14.3485 52.9893,14.8016 C46.9229,17.1844 39.1413,15.37582 34.0203,12.2704 C33.11796,11.82899 32.7586,11.94228 31.9265,12.2704 L31.9263,12.2699 Z M34.9888,17.1801 C39.9263,19.434 45.9658,20.5512 51.7388,19.1801 C52.07864,26.3676 51.715363,32.2111 50.89505,37.0041 L34.98905,37.0041 L34.9888,17.1801 Z M15.8638,41.0081 L30.9888,41.0081 L30.9888,60.3671 C27.9341,58.5351 24.3482,56.6874 21.1138,52.5507 C19.0357,49.8945 17.1568,46.203 15.8638,41.0117 L15.8638,41.0081 Z" id="Shape" fill="#000" fill-rule="nonzero"/></g></svg>
#
#       <b>Safety Zone</b>
# </a>
#   </div>
#
# </div>
#
#
#     <div id="main" class="main" role="main">
#
#
# <div class="search-controls" data-component="search-controls">
#   <div class="search-controls-inner">
#
#     <div class="search-controls-display-options">
#
#       <label class="vh" for="unique">Show</label>
#       <select name="unique" id="unique" title="Change how cards are found" class="select-n" v-on:change="reloadSearch"><option value="cards">Cards</option>
# <option selected="selected" value="prints">All prints</option>
# <option value="art">Unique art</option></select>
#
#       <label for="as">as</label>
#       <select name="as" id="as" title="Change how cards are displayed" class="select-n" v-on:change="reloadSearch"><option selected="selected" value="grid">Images</option>
# <option value="checklist">Checklist</option>
# <option value="text">Text Only</option>
# <option value="full">Full</option></select>
#
#       <label for="order">sorted by</label>
#       <select name="order" id="order" title="Change how cards are sorted" class="select-n" v-on:change="reloadSearch"><option value="name">Name</option>
# <option value="released">Release Date</option>
# <option selected="selected" value="set">Set/Number</option>
# <option value="rarity">Rarity</option>
# <option value="color">Color</option>
# <option value="usd">Price: USD</option>
# <option value="tix">Price: TIX</option>
# <option value="eur">Price: EUR</option>
# <option value="cmc">Mana Value</option>
# <option value="power">Power</option>
# <option value="toughness">Toughness</option>
# <option value="artist">Artist Name</option>
# <option value="edhrec">EDHREC Rank</option>
# <option value="review">Set Review</option></select>
#
#       <label title="Sort direction" for="dir">:</label>
#       <select name="dir" id="dir" class="select-n" title="Change sort direction, ascending or descending" v-on:change="reloadSearch"><option value="">Auto</option>
# <option value="asc">Asc</option>
# <option value="desc">Desc</option></select>
#
#     </div>
#
#     <div class="search-controls-pagination">
#
#         <span aria-hidden="true" class="button-n disabled icon-only">
#           <svg width="30" height="30" viewBox="0 0 30 30" aria-hidden="true" focusable="false" xmlns="http://www.w3.org/2000/svg"><path d="M18 4.438l-1.375-1.438-12.625 12 12.563 12 1.437-1.406-11.094-10.594 11.094-10.562zm12 0l-1.375-1.438-12.625 12 12.563 12 1.437-1.406-11.094-10.594 11.094-10.562zM2 3h-1.66v24h1.66z"/></svg>
#
#           <b class="vh">First Page</b>
# </span>        <span aria-hidden="true" class="button-n disabled">
#           <svg width="30" height="30" viewBox="0 0 30 30" aria-hidden="true" focusable="false" xmlns="http://www.w3.org/2000/svg"><path d="M20.625 3l-12.625 12 12.563 12 1.437-1.406-11.094-10.594 11.094-10.562z"/></svg>
#
#           <b>Previous</b>
# </span>
#         <a class="button-n" href="/search?as=grid&amp;order=set&amp;page=2&amp;q=%28e%3Altr+cn%3E%3D452%29+or+%28e%3Altc+cn%3E%3D411%29&amp;unique=prints">
#           <b>Next 60</b>
#           <svg width="30" height="30" viewBox="0 0 30 30" aria-hidden="true" focusable="false" xmlns="http://www.w3.org/2000/svg"><path d="M9.375 3l12.625 12-12.562 12-1.438-1.406 11.094-10.594-11.094-10.562z"/></svg>
#
# </a>        <a class="button-n icon-only" href="/search?as=grid&amp;order=set&amp;page=10&amp;q=%28e%3Altr+cn%3E%3D452%29+or+%28e%3Altc+cn%3E%3D411%29&amp;unique=prints">
#           <svg width="30" height="30" viewBox="0 0 30 30" aria-hidden="true" focusable="false" xmlns="http://www.w3.org/2000/svg"><path d="M12 4.438l1.375-1.438 12.625 12-12.563 12-1.437-1.406 11.094-10.594-11.094-10.562zm-12 0l1.375-1.438 12.625 12-12.563 12-1.437-1.406 11.094-10.594-11.094-10.562zM28 3h1.66v24h-1.66z"/></svg>
#
#           <b class="vh">Last Page</b>
# </a>
#     </div>
#
#   </div>
# </div>
#
# <form class="search-controls-mobile" data-component="search-controls-mobile" action="/search" accept-charset="UTF-8" method="get">
#
#   <input type="hidden" name="q" id="q" value="(e:ltr cn&gt;=452) or (e:ltc cn&gt;=411)" autocomplete="off" />
#
#   <div class="search-controls-mobile-inner">
#
#       <span aria-hidden="true" class="button-n disabled">
#         <svg width="30" height="30" viewBox="0 0 30 30" aria-hidden="true" focusable="false" xmlns="http://www.w3.org/2000/svg"><path d="M20.625 3l-12.625 12 12.563 12 1.437-1.406-11.094-10.594 11.094-10.562z"/></svg>
#
#         <b>Previous</b>
# </span>
#     <button type="button" class="button-n" v-on:click="toggleOptions()" v-bind:class="{'primary-n':optionsOpen}">
#       <svg focusable="false"  aria-hidden="true"  viewBox="0 0 100 100" xmlns="http://www.w3.org/2000/svg"><path d="M93.633 93.812a1.985 1.985 0 0 1 0 2.805l-2.805 2.804a1.985 1.985 0 0 1-2.804 0L68.387 79.784a1.956 1.956 0 0 1-.454-.734c-4.027 2.941-8.972 4.7-14.344 4.7-13.46 0-24.375-10.91-24.375-24.372 0-13.46 10.914-24.375 24.375-24.375s24.375 10.914 24.375 24.375c0 5.371-1.757 10.316-4.699 14.344.27.094.52.235.735.453zM53.59 43.132c-8.973 0-16.25 7.273-16.25 16.25 0 8.973 7.273 16.246 16.25 16.246 8.973 0 16.25-7.273 16.25-16.246 0-8.977-7.277-16.25-16.25-16.25zM4.68 28.594h59.184v-6.281H4.68zm0-22.496v6.281h59.184V6.098zm0 38.707h22.102a30.283 30.283 0 0 1 4.664-6.281l-26.766.004zm0 9.938v6.28h18.383c-.028-.527-.078-1.046-.078-1.577 0-1.602.164-3.164.402-4.703z"/></svg>
#
#       <b>View</b>
#     </button>
#
#       <a class="button-n" href="/search?as=grid&amp;order=set&amp;page=2&amp;q=%28e%3Altr+cn%3E%3D452%29+or+%28e%3Altc+cn%3E%3D411%29&amp;unique=prints">
#         <b>Next 60</b>
#         <svg width="30" height="30" viewBox="0 0 30 30" aria-hidden="true" focusable="false" xmlns="http://www.w3.org/2000/svg"><path d="M9.375 3l12.625 12-12.562 12-1.438-1.406 11.094-10.594-11.094-10.562z"/></svg>
#
# </a>
#   </div>
#
#   <div class="search-controls-mobile-options" v-bind:class="{open:optionsOpen}">
#
#     <div class="search-controls-mobile-option">
#       <label for="unique">Find</label>
#       <select name="unique" id="unique" title="Change how cards are found" class="select-n"><option value="cards">Cards</option>
# <option selected="selected" value="prints">All prints</option>
# <option value="art">Unique art</option></select>
#     </div>
#
#     <div class="search-controls-mobile-option">
#       <label for="as">Display as</label>
#       <select name="as" id="as" title="Change how cards are displayed" class="select-n"><option selected="selected" value="grid">Images</option>
# <option value="checklist">Checklist</option>
# <option value="text">Text Only</option>
# <option value="full">Full</option></select>
#     </div>
#
#     <div class="search-controls-mobile-option">
#       <label for="order">Sorted by</label>
#       <select name="order" id="order" title="Change how cards are sorted" class="select-n"><option value="name">Name</option>
# <option value="released">Release Date</option>
# <option selected="selected" value="set">Set/Number</option>
# <option value="rarity">Rarity</option>
# <option value="color">Color</option>
# <option value="usd">Price: USD</option>
# <option value="tix">Price: TIX</option>
# <option value="eur">Price: EUR</option>
# <option value="cmc">Mana Value</option>
# <option value="power">Power</option>
# <option value="toughness">Toughness</option>
# <option value="artist">Artist Name</option>
# <option value="edhrec">EDHREC Rank</option>
# <option value="review">Set Review</option></select>
#     </div>
#
#     <div class="search-controls-mobile-option">
#       <label for="dir">Sort direction</label>
#       <select name="dir" id="dir" class="select-n" title="Change sort direction, ascending or descending"><option value="">Auto</option>
# <option value="asc">Asc</option>
# <option value="desc">Desc</option></select>
#     </div>
#
#     <div class="search-controls-mobile-option">
#       <button type="submit" class="button-n primary-n">Search with these options</button>
#     </div>
#
#
#   </div>
#
# </form>
#
#   <div class="search-info">
#     <p>
#       <strong>1 – 60 <i>of</i> 550 cards</strong>
#       <span class="search-summary-english">where (the set is “ltr” and the collector number &gt;= 452) or (the set is “ltc” and the collector number &gt;= 411)</span>
#     </p>
#   </div>
#
#
#
#
#
#
#
# <div class="card-grid">
#   <div class="card-grid-inner">
#
#
#
#       <div class="card-grid-item " data-card-id="2ed1e876-f68f-4134-bb63-f9d05d5e0cff">
#
#         <a class="card-grid-item-card" href="https://scryfall.com/card/ltc/411/beregond-of-the-guard">
#
#
#           <span class="card-grid-item-invisible-label" aria-hidden="true">Beregond of the Guard</span>
#
#
#           <div class="card-grid-item-card-faces" v-bind:class="{'flipped':flipped}">
#
#             <div class="card-grid-item-card-front">
#               <img class="card ltc border-black " title="Beregond of the Guard (Tales of Middle-earth Commander #411)" alt="Beregond of the Guard (Tales of Middle-earth Commander #411)" loading="eager" src="https://cards.scryfall.io/normal/front/2/e/2ed1e876-f68f-4134-bb63-f9d05d5e0cff.jpg?1695448280" />
#             </div>
#
#
#           </div>
#
#
# </a>
#
# </div>
#
#       <div class="card-grid-item " data-card-id="7ba2acdb-2c88-43f0-bacf-d9ec7bd011bb">
#
#         <a class="card-grid-item-card" href="https://scryfall.com/card/ltc/412/champions-of-minas-tirith">
#
#
#           <span class="card-grid-item-invisible-label" aria-hidden="true">Champions of Minas Tirith</span>
#
#
#           <div class="card-grid-item-card-faces" v-bind:class="{'flipped':flipped}">
#
#             <div class="card-grid-item-card-front">
#               <img class="card ltc border-black " title="Champions of Minas Tirith (Tales of Middle-earth Commander #412)" alt="Champions of Minas Tirith (Tales of Middle-earth Commander #412)" loading="eager" src="https://cards.scryfall.io/normal/front/7/b/7ba2acdb-2c88-43f0-bacf-d9ec7bd011bb.jpg?1695448344" />
#             </div>
#
#
#           </div>
#
#
# </a>
#
# </div>
#
#       <div class="card-grid-item " data-card-id="599234de-4bbc-4c9b-84a2-c426e64597ff">
#
#         <a class="card-grid-item-card" href="https://scryfall.com/card/ltc/413/field-tested-frying-pan">
#
#
#           <span class="card-grid-item-invisible-label" aria-hidden="true">Field-Tested Frying Pan</span>
#
#
#           <div class="card-grid-item-card-faces" v-bind:class="{'flipped':flipped}">
#
#             <div class="card-grid-item-card-front">
#               <img class="card ltc border-black " title="Field-Tested Frying Pan (Tales of Middle-earth Commander #413)" alt="Field-Tested Frying Pan (Tales of Middle-earth Commander #413)" loading="eager" src="https://cards.scryfall.io/normal/front/5/9/599234de-4bbc-4c9b-84a2-c426e64597ff.jpg?1695448351" />
#             </div>
#
#
#           </div>
#
#
# </a>
#
# </div>
#
#       <div class="card-grid-item " data-card-id
span>
#
#
#           <div class="card-grid-item-card-faces" v-bind:class="{'flipped':flipped}">
#
#             <div class="card-grid-item-card-front">
#               <img class="card ltc border-black " title="Rapacious Guest (Tales of Middle-earth Commander #430)" alt="Rapacious Guest (Tales of Middle-earth Commander #430)" loading="eager" src="https://cards.scryfall.io/normal/front/6/8/685c72fb-ebb8-4474-bd73-bcbbbc38c496.jpg?1695447754" />
#             </div>
#
#
#           </div>
#
#
# </a>
#
# </div>
#
#       <div class="card-grid-item " data-card-id="420080db-9b6a-4179-8c09-3aa3ff9a1bb5">
#
#         <a class="card-grid-item-card" href="https://scryfall.com/card/ltc/431/shelob-dread-weaver">
#
#
#           <span class="card-grid-item-invisible-label" aria-hidden="true">Shelob, Dread Weaver</span>
#
#
#           <div class="card-grid-item-card-faces" v-bind:class="{'flipped':flipped}">
#
#             <div class="card-grid-item-card-front">
# ...
#           <svg focusable="false"  aria-hidden="true"  width="15" height="15" viewBox="0 0 15 15" xmlns="http://www.w3.org/2000/svg"><g fill="#000" fill-rule="evenodd"><path d="M8 13h1.718c.446 0 .607-.046.77-.134.163-.087.29-.215.378-.378.088-.163.134-.324.134-.77V2.282c0-.446-.046-.607-.134-.77-.087-.163-.215-.29-.378-.378-.163-.088-.324-.134-.77-.134H2.282c-.446 0-.607.046-.77.134-.163.087-.29.215-.378.378-.088.163-.134.324-.134.77v9.436c0 .446.046.607.134.77.087.163.215.29.378.378.163.088.324.134.77.134H4c0-.552.895-1 2-1s2 .448 2 1zM1 0h10c.552 0 1 .448 1 1v13c0 .552-.448 1-1 1H1c-.552 0-1-.448-1-1V1c0-.552.448-1 1-1zm5 13.5c.552 0 1-.224 1-.5s-.448-.5-1-.5-1 .224-1 .5.448.5 1 .5zM12 13h.718c.446 0 .607-.046.77-.134.163-.087.29-.215.378-.378.088-.163.134-.324.134-.77V2.282c0-.446-.046-.607-.134-.77-.087-.163-.215-.29-.378-.378-.163-.088-.324-.134-.77-.134H12V0h2c.552 0 1 .448 1 1v13c0 .552-.448 1-1 1h-2v-2z"/></g></svg>
#
#           <b>Working on: {{truncatedDeckName(activeDeck.name)}}</b>
#         </a>
#       </li>
#       <li v-for="deck in recentDecks" class="deck-tray-option">
#         <button v-on:click="updateActiveDeck(deck)" type="button" class="button-n align-left" v-bind:title="deck.name">
#           <svg focusable="false"  aria-hidden="true"  width="15" height="15" viewBox="0 0 15 15" xmlns="http://www.w3.org/2000/svg"><g fill="#000" fill-rule="evenodd"><path d="M8 13h1.718c.446 0 .607-.046.77-.134.163-.087.29-.215.378-.378.088-.163.134-.324.134-.77V2.282c0-.446-.046-.607-.134-.77-.087-.163-.215-.29-.378-.378-.163-.088-.324-.134-.77-.134H2.282c-.446 0-.607.046-.77.134-.163.087-.29.215-.378.378-.088.163-.134.324-.134.77v9.436c0 .446.046.607.134.77.087.163.215.29.378.378.163.088.324.134.77.134H4c0-.552.895-1 2-1s2 .448 2 1zM1 0h10c.552 0 1 .448 1 1v13c0 .552-.448 1-1 1H1c-.552 0-1-.448-1-1V1c0-.552.448-1 1-1zm5 13.5c.552 0 1-.224 1-.5s-.448-.5-1-.5-1 .224-1 .5.448.5 1 .5zM12 13h.718c.446 0 .607-.046.77-.134.163-.087.29-.215.378-.378.088-.163.134-.324.134-.77V2.282c0-.446-.046-.607-.134-.77-.087-.163-.215-.29-.378-.378-.163-.088-.324-.134-.77-.134H12V0h2c.552 0 1 .448 1 1v13c0 .552-.448 1-1 1h-2v-2z"/></g></svg>
#
#           <b>Switch to: {{truncatedDeckName(deck.name)}}</b>
#         </button>
#       </li>
#       <li class="deck-tray-option">
#         <button v-on:click="createNewList()" type="button" class="button-n align-left">
#           <svg focusable="false"  aria-hidden="true"  viewBox="0 0 16 15" xmlns="http://www.w3.org/2000/svg"><path d="M14.698 11.786h-2.569v1.071c0 .179.024.349.061.515l.035.127.13.356.035.073h1.352l.159-.02c.591-.076 1.041-.643 1.041-1.319 0-.295-.084-.575-.244-.804v.001zm-3.506-9.313c0-.773-.553-1.401-1.228-1.401H7.703a2.354 2.354 0 0 0-.261 1.071c0 1.184.844 2.143 1.875 2.143H3.692v8.241c0 .774.553 1.401 1.228 1.401h6.432a3.64 3.64 0 0 1-.159-1.071V2.474l-.001-.001zm-9.375-.33c0 .59.422 1.071.938 1.071h3.91a3.646 3.646 0 0 1-.159-1.071c0-.375.056-.736.159-1.071h-3.91c-.516 0-.938.481-.938 1.071zm12.188 12.83V15H4.92c-1.2 0-2.166-1.108-2.166-2.473V4.286c-1.031 0-1.875-.959-1.875-2.143C.879.96 1.723 0 2.754 0h7.21c1.2 0 2.166 1.108 2.166 2.473v8.241h2.953c.488.438.797 1.111.797 1.875 0 1.239-.825 2.249-1.875 2.384z" fill="#000" fill-rule="nonzero"/></svg>
#
#           <b>Start a new quick List</b>
#         </button>
#       </li>
#       <li class="deck-tray-option">
#         <a href="#" v-bind:href="decksURI()" class="button-n align-left">
#           <svg focusable="false"  aria-hidden="true"  xmlns="http://www.w3.org/2000/svg" viewBox="0 0 448 512"><path d="M320 64h-16V48c0-26.47-21.53-48-48-48h-64c-26.47 0-48 21.53-48 48v16h-16C57.31 64 0 121.31 0 192v256c0 35.35 28.65 64 64 64h320c35.35 0 64-28.65 64-64V192c0-70.69-57.31-128-128-128zM176 48c0-8.83 7.19-16 16-16h64c8.81 0 16 7.17 16 16v16h-96V48zm160 432H112v-96h224v96zm0-128H112v-32c0-17.67 14.33-32 32-32h160c17.67 0 32 14.33 32 32v32zm80 96c0 17.64-14.36 32-32 32h-16V320c0-35.29-28.71-64-64-64H144c-35.29 0-64 28.71-64 64v160H64c-17.64 0-32-14.36-32-32V192c0-52.94 43.06-96 96-96h192c52.94 0 96 43.06 96 96v256zM312 160H136c-4.42 0-8 3.58-8 8v16c0 4.42 3.58 8 8 8h176c4.42 0 8-3.58 8-8v-16c0-4.42-3.58-8-8-8z"/></svg>
#
#           <b>View your decks</b>
#         </a>
#       </li>
#       <li class="deck-tray-option">
#         <button v-on:click="clearActiveDeck()" type="button" class="button-n danger align-left">
#           <svg focusable="false"  aria-hidden="true"  xmlns="http://www.w3.org/2000/svg" viewBox="0 0 384 512"><path d="M217.5 256l137.2-137.2c4.7-4.7 4.7-12.3 0-17l-8.5-8.5c-4.7-4.7-12.3-4.7-17 0L192 230.5 54.8 93.4c-4.7-4.7-12.3-4.7-17 0l-8.5 8.5c-4.7 4.7-4.7 12.3 0 17L166.5 256 29.4 393.2c-4.7 4.7-4.7 12.3 0 17l8.5 8.5c4.7 4.7 12.3 4.7 17 0L192 281.5l137.2 137.2c4.7 4.7 12.3 4.7 17 0l8.5-8.5c4.7-4.7 4.7-12.3 0-17L217.5 256z" fill="#FFF" /></svg>
#
#           <b>Dismiss this tray</b>
#         </button>
#       </li>
#     </ol>
#     <div v-if="activeDeck" class="deck-tray-buttons">
#       <button v-on:click="toggleExpansion()" type="button" title="Show deckbuilder tools" class="button-n primary icon-only subdued">
#         <svg focusable="false"  aria-hidden="true"  xmlns="http://www.w3.org/2000/svg" viewBox="0 0 448 512"><path d="M320 64h-16V48c0-26.47-21.53-48-48-48h-64c-26.47 0-48 21.53-48 48v16h-16C57.31 64 0 121.31 0 192v256c0 35.35 28.65 64 64 64h320c35.35 0 64-28.65 64-64V192c0-70.69-57.31-128-128-128zM176 48c0-8.83 7.19-16 16-16h64c8.81 0 16 7.17 16 16v16h-96V48zm160 432H112v-96h224v96zm0-128H112v-32c0-17.67 14.33-32 32-32h160c17.67 0 32 14.33 32 32v32zm80 96c0 17.64-14.36 32-32 32h-16V320c0-35.29-28.71-64-64-64H144c-35.29 0-64 28.71-64 64v160H64c-17.64 0-32-14.36-32-32V192c0-52.94 43.06-96 96-96h192c52.94 0 96 43.06 96 96v256zM312 160H136c-4.42 0-8 3.58-8 8v16c0 4.42 3.58 8 8 8h176c4.42 0 8-3.58 8-8v-16c0-4.42-3.58-8-8-8z"/></svg>
#
#         <span class="vh">Open your active deck</span>
#       </button>
#     </div>
#   </div>
# </script>
#
#     <div id="x-mount-admin-tray"></div>
# <script type="template" id="x-template-admin-tray" aria-hidden="true">
#   <div id="admin-tray" class="admin-tray">
#
#     <template v-if="cardOperationsShown()">
#
#       <a title="Edit Card" class="button-n primary icon-only subdued" rel="nofollow" v-bind:href="uris.cardEditURI">
#         <svg focusable="false"  aria-hidden="true"  xmlns="http://www.w3.org/2000/svg" viewBox="0 0 512 512"><path fill="#676671" d="M491.609 73.625l-53.861-53.839c-26.378-26.379-69.076-26.383-95.46-.001L24.91 335.089.329 484.085c-2.675 16.215 11.368 30.261 27.587 27.587l148.995-24.582 315.326-317.378c26.33-26.331 26.581-68.879-.628-96.087zM120.644 302l170.259-169.155 88.251 88.251L210 391.355V350h-48v-48h-41.356zM82.132 458.132l-28.263-28.263 12.14-73.587L84.409 338H126v48h48v41.59l-18.282 18.401-73.586 12.141zm378.985-319.533l-.051.051-.051.051-48.03 48.344-88.03-88.03 48.344-48.03.05-.05.05-.05c9.147-9.146 23.978-9.259 33.236-.001l53.854 53.854c9.878 9.877 9.939 24.549.628 33.861z"/></svg>
#
#       </a>
#
#       <a title="New Reprint" class="button-n primary icon-only subdued" rel="nofollow" v-bind:href="uris.cardReprintURI" v-show="!optionKeyIsDown">
#         <svg focusable="false"  aria-hidden="true"  viewBox="0 0 448 512" xmlns="http://www.w3.org/2000/svg"><path d="M433.941 65.941l-51.882-51.882A48 48 0 0 0 348.118 0H176c-26.51 0-48 21.49-48 48v48H48c-26.51 0-48 21.49-48 48v320c0 26.51 21.49 48 48 48h224c26.51 0 48-21.49 48-48v-48h80c26.51 0 48-21.49 48-48V99.882a48 48 0 0 0-14.059-33.94v-.001zM288 464c0 8.822-7.178 16-16 16H48c-8.822 0-16-7.178-16-16V144c0-8.822 7.178-16 16-16h80v240c0 26.51 21.49 48 48 48h112v48zm128-96c0 8.822-7.178 16-16 16H176c-8.822 0-16-7.178-16-16V48c0-8.822 7.178-16 16-16h144l96 96v240z" fill="#000" fill-rule="nonzero"/></svg>
#
#       </a>
#
#       <a title="New Reprint With Similar Data" class="button-n primary icon-only subdued" rel="nofollow" v-bind:href="uris.cardCloneURI" v-show="optionKeyIsDown" v-on:click="openIgnoringOptionKey">
#         <svg focusable="false"  aria-hidden="true"  viewBox="0 0 448 512" xmlns="http://www.w3.org/2000/svg"
svg focusable="false"  aria-hidden="true"  xmlns="http://www.w3.org/2000/svg" viewBox="0 0 448 512"><path d="M224 32c106 0 192 28.75 192 64v32c0 35.25-86 64-192 64S32 163.25 32 128V96c0-35.25 86-64 192-64m192 149.5V224c0 35.25-86 64-192 64S32 259.25 32 224v-42.5c41.25 29 116.75 42.5 192 42.5s150.749-13.5 192-42.5m0 96V320c0 35.25-86 64-192 64S32 355.25 32 320v-42.5c41.25 29 116.75 42.5 192 42.5s150.749-13.5 192-42.5m0 96V416c0 35.25-86 64-192 64S32 451.25 32 416v-42.5c41.25 29 116.75 42.5 192 42.5s150.749-13.5 192-42.5M224 0C145.858 0 0 18.801 0 96v320c0 77.338 146.096 96 224 96 78.142 0 224-18.801 224-96V96c0-77.338-146.096-96-224-96z"/></svg>
#
# </a>
#
#     <button name="button" type="button" v-bind:title="cacheButtonLabel()" class="button-n primary icon-only subdued" rel="nofollow" v-on:click="clearCaches" v-bind:class="{pop:cacheClearing}">
#       <svg focusable="false"  aria-hidden="true"  viewBox="0 0 91 91" xmlns="http://www.w3.org/2000/svg"><g fill="#000" fill-rule="nonzero"><path d="M84.398 40.398H67.5A5.591 5.591 0 0 0 61.898 46c0 3.101 2.5 5.601 5.602 5.601h16.898C87.5 51.601 90 49.101 90 46c0-3.102-2.5-5.602-5.602-5.602zM28.102 46c0-3.102-2.5-5.602-5.602-5.602H5.602A5.591 5.591 0 0 0 .001 46c0 3.102 2.5 5.602 5.601 5.602H22.5c3.102 0 5.602-2.5 5.602-5.602zM53.398 31.398c2.7 1.602 6.102.602 7.7-2.102l8.398-14.602c1.601-2.699.601-6.101-2.102-7.699-2.7-1.601-6.102-.601-7.7 2.102l-8.398 14.602a5.708 5.708 0 0 0 2.102 7.699zM36.602 60.602c-2.7-1.602-6.102-.602-7.7 2.102l-8.398 14.602c-1.601 2.699-.601 6.101 2.102 7.699 2.7 1.601 6.102.601 7.7-2.102l8.398-14.602a5.708 5.708 0 0 0-2.102-7.699zM30.199 9.102A5.706 5.706 0 0 0 22.499 7c-2.698 1.5-3.6 5-2.1 7.7l8.398 14.602c1.601 2.699 5 3.601 7.699 2.101 2.699-1.601 3.601-5 2.101-7.699L30.2 9.102zM61.102 62.699a5.706 5.706 0 0 0-7.7-2.102 5.706 5.706 0 0 0-2.1 7.7L59.7 82.899c1.601 2.699 5 3.601 7.699 2.101C70.098 83.4 71 80 69.5 77.301l-8.398-14.602zM13.102 30.898l7.3 4.2c1.302.8 3.102.3 3.802-1 .8-1.302.3-3.102-1-3.802L16 26c-1.3-.801-3.101-.301-3.8 1-.899 1.398-.399 3.101.902 3.898zM76.898 61.102l-7.3-4.2c-1.302-.8-3.102-.3-3.802 1-.8 1.302-.3 3.102 1 3.802L74 66c1.301.8 3.102.3 3.801-1 .899-1.399.399-3.102-.902-3.899zM24.301 58c-.8-1.3-2.5-1.8-3.8-1l-7.302 4.2c-1.3.8-1.8 2.5-1 3.8.801 1.3 2.5 1.8 3.801 1l7.301-4.2c1.3-.8 1.8-2.5 1-3.8zM65.699 34c.8 1.3 2.5 1.8 3.8 1l7.302-4.2c1.3-.8 1.8-2.5 1-3.8C77 25.7 75.3 25.2 74 26l-7.301 4.2c-1.3.8-1.8 2.5-1 3.8zM45 69.898c-1.602 0-2.8 1.3-2.8 2.8v8.4c0 1.6 1.3 2.8 2.8 2.8 1.5 0 2.8-1.3 2.8-2.8v-8.4c0-1.5-1.198-2.8-2.8-2.8zM45 8c-1.602 0-2.8 1.3-2.8 2.8v8.4c0 1.6 1.3 2.8 2.8 2.8 1.5 0 2.8-1.3 2.8-2.8v-8.4C47.8 9.3 46.603 8 45 8z"/></g></svg>
#
# </button>
#     <a title="Open Admin" class="button-n primary icon-only subdued" rel="nofollow" href="/admin">
#       <svg focusable="false"  aria-hidden="true"  xmlns="http://www.w3.org/2000/svg" width="30" height="30" viewBox="0 0 30 30"><path d="M14 30h2v-2.051c1.642-.125 3.193-.557 4.608-1.234l1.025 1.775 1.731-1-1.021-1.768c1.323-.908 2.47-2.055 3.378-3.377l1.768 1.02.999-1.731-1.775-1.024c.679-1.415 1.11-2.968 1.235-4.609h2.052v-2h-2.051c-.125-1.642-.557-3.193-1.235-4.608l1.776-1.025-1-1.732-1.768 1.021c-.908-1.322-2.055-2.469-3.377-3.377l1.021-1.768-1.732-1-1.025 1.775c-1.416-.68-2.967-1.111-4.609-1.236v-2.051h-2v2.051c-1.642.125-3.193.557-4.608 1.234l-1.026-1.775-1.732 1 1.021 1.768c-1.323.908-2.469 2.054-3.378 3.376l-1.767-1.02-1.001 1.731 1.777 1.026c-.679 1.416-1.11 2.967-1.235 4.609h-2.051v2h2.051c.125 1.642.557 3.193 1.235 4.608l-1.776 1.026 1 1.732 1.768-1.021c.908 1.322 2.055 2.469 3.377 3.377l-1.021 1.768 1.732 1 1.025-1.775c1.415.678 2.967 1.109 4.608 1.234v2.051zm1-4c-1.647 0-3.204-.372-4.606-1.021l3.544-6.139c.34.094.692.16 1.062.16 1.861 0 3.412-1.277 3.858-3h7.091c-.506 5.605-5.212 10-10.949 10zm0-13c1.104 0 2 .896 2 2s-.896 2-2 2-2-.896-2-2 .896-2 2-2zm10.949 1h-7.091c-.446-1.723-1.997-3-3.858-3-.37 0-.722.066-1.063.16l-3.544-6.139c1.403-.649 2.96-1.021 4.607-1.021 5.737 0 10.443 4.395 10.949 10zm-21.949 1c0-3.712 1.844-6.988 4.66-8.98l3.539 6.129c-.739.726-1.199 1.734-1.199 2.851s.46 2.125 1.199 2.852l-3.539 6.128c-2.816-1.992-4.66-5.268-4.66-8.98z"/></svg>
# </a>
#   </div>
# </script>
#
#     <div id="x-mount-caster-tray"></div>
# <script type="template" id="x-template-caster-tray">
#   <div id="caster-tray" class="caster-tray">
#     <a class="button-n primary-n" href="/settings/preferences">
#       Caster Mode is ON
# </a>  </div>
# </script>
#
#     <div id="card-tooltip" aria-hidden="true"></div>
#     <script src="https://scryfall.com/assets/scryfall-607e8d6799e783b0340db4b47f894ad806c36eafb267595caef68f1eacb0739a.js"></script>
#     <script src="https://www.googletagmanager.com/gtag/js?id=G-3P82LCZY01" async="async"></script>
#     <script src="https://static.cloudflareinsights.com/beacon.min.js?token=5d64c17775954f64a21257761c8197d9" defer="defer"></script>
#
#   </body>
# </html>

# %%
zip_to_yolov8_directory(open('images.zip', 'rb'))
